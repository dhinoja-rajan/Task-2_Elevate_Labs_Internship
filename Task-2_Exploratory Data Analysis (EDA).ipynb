# %% [markdown]
# # ***Task 2: Exploratory Data Analysis (EDA):-***

# %% [markdown]
# ## Import Required Dependencies:-
# Import essential libraries and modules for data manipulation, visualization, and preprocessing...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

print("✅ Required Libraries are Imported - Done!\n")
# Out:
# ✅ Required Libraries are Imported - Done!

# %% [markdown]
# ## Load the Dataset:-

# %%
dataset = pd.DataFrame(pd.read_csv('./Titanic-Dataset.csv'))
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Categroical and Numerical Columns

# %%
categorical_cols = dataset.select_dtypes(include=['object']).columns
numerical_cols = dataset.select_dtypes(exclude=['object']).columns

if categorical_cols.empty:
  print("❌ No Categorical Columns Found...")
else:
  print("✅ Categorical Columns found: \n", categorical_cols, "\n")

if numerical_cols.empty:
  print("❌ No Numerical Columns Found...")
else:
  print("✅ Numerical Columns found: \n", numerical_cols)
# Out:
# ✅ Categorical Columns found:
#  Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')
#
# ✅ Numerical Columns found:
#  Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %% [markdown]
# ## Summary Statistics (mean, median, std, etc.).

# %%
print("> Statistical summary of the Dataset:")
print(dataset.describe().to_string(header=True), "\n")

print("median:")
print(dataset.median(numeric_only=True))
# Out:
# > Statistical summary of the Dataset:
#        PassengerId    Survived      Pclass         Age       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000    6.000000  512.329200
#
# median:
# PassengerId    446.0000
# Survived         0.0000
# Pclass           3.0000
# Age             28.0000
# ...

# %%
# Correlation Matrix Heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(dataset[numerical_cols].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix \n',fontsize=20,  fontweight=800)
plt.show()

# %% [markdown]
# ## Different Plots:-

# %% [markdown]
# ### Checking Valid Cols

# %%
valid_cols = []
for col in dataset.columns:
    unique_values = dataset[col].unique()
    if len(unique_values) < 20:
        # print(col, len(unique_values))
        valid_cols.append(col)

print(valid_cols)
# Out:
# ['Survived', 'Pclass', 'Sex', 'SibSp', 'Parch', 'Embarked']

# %% [markdown]
# ### Histplots/ Histograms

# %%
for col in valid_cols:
    plt.figure()
    sns.histplot(dataset[col].dropna(), kde=True, bins=40, color='blue')
    plt.title(f'Histogram of {col}')
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()

# %% [markdown]
# ### Boxplots

# %%
for col in valid_cols:
    plt.figure()
    sns.boxplot(dataset[col], color="blue")
    plt.title(f'Boxplot of {col}')
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()

# %% [markdown]
# ### Pairplots

# %%
sns.pairplot(dataset.dropna(), hue='Survived')
plt.suptitle("Pairplot of Key Features", fontweight=800, fontsize=20)
plt.show()

# %% [markdown]
# ### Countplots

# %%
for col in valid_cols:
    plt.figure()
    sns.countplot(x=col, data=dataset)
    plt.title(f'Countplot of {col}')
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()
